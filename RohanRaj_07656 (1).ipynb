# %% [markdown]
# # Homework 3
#
# We know graphs are used to represent pair-wise relationships - such as friendship. When we use graphs to represent social relationships then we call them social graphs (aka [social networks](https://en.wikipedia.org/wiki/Social_network)) - such as friendship graphs to represent a friendship relation among a group of people. Similarly, we can use graphs to represent [technological networks](https://www.sci.unich.it/~francesc/teaching/network/technological.html) (such as Power Grid and Internet), [biological networks](https://en.wikipedia.org/wiki/Biological_network) (such as [food web](https://en.wikipedia.org/wiki/Food_web) and [protein-protein interactions](https://en.wikipedia.org/wiki/Protein%E2%80%93protein_interaction), [transport networks](https://en.wikipedia.org/wiki/Transport_network_analysis)(airline and roads networks), and many more kinds of networks. Did you notice the usage of graphs in different domains?
#
# The scholars from different domains have been using graphs to solve different kinds of challenging issues in their respective domains. Social scientists are using graph theory to argue social behaviors in our society whereas people from medicine are using graph theory to understand the working of the brain by analyzing signal patterns of neurons.
#
# In this homework, you will be implementing Graph ADT and will be using this to solve some interesting problems.
#
# **Note:** You can access relevant files at https://github.com/habib-university/cs102-spring22-hw3

# %% [markdown]
# # Task 1: Friendship Network

# %% [markdown]
# ## Task *1.1*: Graph ADT
#
# You have to implement Graph ADT with the following functions. You are free to select an implementation methodology (this can be either using Adjacency List, Adjacency Matrix, Incident Matrix, or Edge list).

# %% [markdown]
# ### Graph consutrction functions

# %%
# return an empty graph
def Create():
  return {}

# Label can be used to identify a vertex in the graph
# this could be a number or a string for example: 1, "Asim"
def Create(nodes):
  # nodes = list of nodes with labels
  G = {}
  for i in nodes:
    G[i] = []
  return G

# %% [markdown]
# ### Basic Functions

# %%
# Add a vertex in the graph with the given label
# Do not add a new vertex if a vertex already exists in the graph for the given label
def AddVertex(graph, label):
  if label not in graph:
    graph[label] = []
  return graph

# Delete the vertex source the graph having the same label as provided
def DeleteVertex(graph, label):
  del graph[label]
  for i in graph:
    for j in graph[i]:
      if j[0] == label:
        graph[i].remove(j)

# Delete vertices source the graph for the given labels
def DeleteVertices(graph, labels):
  # labels: a list
  for i in labels:
    if i in graphs:
      DeleteVertex(graph, label)
  return G

# For the following functions, do not add/delete an edge if any vertex involved in the edge does not exist.

# Add an edge in the graph
def AddEdge(graph, source, target, directed):
  # source: label to identify the source vertex
  # target: lbael to identify the target vertex
  # directed: whether the edge is directed or undirected
  graph[source].append((target, 1))
  if directed == False:
    graph[target].append((source, 1))


# Add an edge in the graph with a weight
def AddWeightedEdge(graph, source, target, weight, directed):
  # source: label to identify the source vertex
  # target: label to identify the target vertex
  # weight: the weight of the edge
  # directed: whether the edge is directed or undirected
  graph[source].append((target, weight))
  if directed == False:
    graph[target].append((source, weight))

# Add edges in the graph
def AddEdges(graph, edges, directed):
  # edges: a list containing tuples in the form of (source, target)
  #         where 'source' is the label of the source vertex and 
  #         'target' is the label of the target vertex
  # directed: whether edges are directed or undirected
  for i in edges:
    graph = AddEdge(graph, i[0], i[1], i[2], directed)
  return graph

# Add weighted edges in the graph
def AddWeightedEdges(graph, weighted_edges, directed):
  # edges: a list containing tuples in the form of (source, target, weight)
  #         where 'source' is the label of the source vertex, and 
  #         'target' is the label of the target vertex, and
  #         'weight' is the weight of the edge
  # directed: whether edges are directed or undirected
  for i in weighted_edges:
    graph = AddWeightedEdge(graph, i[0], i[1], i[2], directed)
  return graph

# delete an edge from the graph 
def DeleteEdge(graph, source, target):
  for i in range (len(graph[source])):
    if graph[source][i][0] == target:
      del graph[source][i]
      break
  return graph

# delete set of edges from the graph
def DeleteEdges(graph, edges):
  # edges: a list of tuples in the form of (source,to)
  for i in edges:
    graph = DeleteEdge(graph, i[0], i[1])
  return graph

# %% [markdown]
# ### Neighborhood functions

# %%
# returns the labels of neighbours of the given vertex 
def Adjacent(graph, label):
  # label: the label of the vertex for which we want to find neighbours
  n = []
  for i in graph[label]:
    n.append(i[0])
  return n

# %% [markdown]
# ### Search functions

# %%
# find the shortest path between vertices 'start' and 'end'
# returns the list of labels of vertices including the 'start' and 'end' vertices
  
def BreadthFirstSearch(graph, start, end):
  q = [start]
  v = []
  while not is_empty(q) and end not in v:
    f = front(q)
    n = []
    for i in G[f]:
      n.append(i[0])
    vertex = front(q)
    if vertex not in v:
      v.append(vertex)
    deQueue(q)
    for j in n:
        if j not in v:
            enQueue(q, j)
  return v

# returns true if a vertex exists for the given label
# otherwise returns false
def IsVertexExists(graph, vertex):
  return (vertex in graph)

# returns true if there is an edge from source to target vertex
def IsEdgeExists(graph, source, target):
  for i in graph[source]:
    if i[0] == target:
      return True
  return False

# returns a tuple in the form of (source, target, weight) 
# if the edge exists from source to target vertex
# otherwise returns None
def GetEdge(graph, source, target):
  if IsEdgeExists(graph, source, target) == True:
    for i in graph[source]:
      if i[0] == target:
        return (source, target, i[1])
  else:
    return None

# %% [markdown]
# ## Task 1.2: Friendship network
#
# We are given a friendship network in form of an edge list. The edges are stored in a file and we have to write a function to load the graph from the file.
#
# The first line of the file contains an integer N where 0 ≤ N ≤ 10^5. The next N lines contain two strings S and T separated by space where S and T are friends.
#
# The following is an example of a test file.
#
# ---
# 5 \\
# Chris Allan \\
# Sara James \\
# James Chris \\
# Daniel Liana \\
# Liana Mason \\
#
# ---
#
# Your task is to write the following functions:
#
# **LoadGraph:** takes fileName (with path), weighted (True if the file contains weighted edges), and directed (True if the edges are directed) as parameters and returns the graph containing edges as defined in the file.
#
# **MutualFriends:** takes graph, v1, and v2 as parameters where v1 and v2 are labels of two vertices and returns a list of mutual friends. If v1 has neighbours X = {v3,v4,v5} and v2 has neighbours Y = {v3,v6,v7} then mutual friends can be find by finding the intersection of X and Y i.e. {v3}
#
# **NumberOfFriends:** takes graph and v1 as parameters where v1 is the label of the vertex and returns the number of friends for the given vertex.
#
# **FriendRank:** takes graph, v1, and v2 as parameters where v1 and v2 are labels of two vertices. It returns the rank of v2 for the vertex v1. A rank is defined as the minimum number of persons involved between v1 and v2 if v1 has to send a message to v2. For example, for the data given above, the Rank of Allan for Sara is 4 as there are 4 people involved if Sara has to send a message to Allan. Similarly, the rank of Daniel for Liana is 1.

# %%
def LoadGraph(fileName, weighted, directed):
  # weighted = True if the edge list contains weight
  # directed = True if the given edge list is for directed graph
  e = []
  v = []
  data = open(fileName, 'r')
  l = int(data.readline())
  for i in range(l):
    x = data.readline.split()
    if x[0] not in v:
      v.append(x[0])
    if x[1] not in v:
      v.append(x[1])
    if weighted = False:
      e.append((x[0], x[1]))
    else:
      e.append((x[0], x[1], x[2]))
  G = Create(nodes)
  if weighted = False:
    return AddEdges(this_graph, edges, directed)
  else:
    return AddWeightedEdges(this_graph, edges, directed)

# return the list of mutural friends for vertices v1 and v2
def MutualFriends(graph, v1, v2):
  # v1, v2: labels of vertices
  s = []
  e1 = graph[v1]
  e2 = graph[v2]
  for i in e1:
    for j in e2:
      if i == j:
        s.append(e1)
  return s

# returns the rank of friend v2 for v1 in terms of distance
def FriendRank(graph, v1, v2):
  return (len(BreadthFirstSearch(graph, v1, v2)) - 1)

# return the number of friends for the vertex v1
def NumberOfFriends(graph, v1):
  return len(graph[v1])

# %% [markdown]
# # Task 2: COVID-19 Patients' Contact Network
#
# You and your friend have decided to start a  project to analyze COVID-19 patients' contact network. Your friend will handle the website creation (they know what they are doing, having experience in Web development). However, it is
#  up to you to create a data structure that manages the patients' contact network information  and to implement several procedures that operate on the network.
#
# On a website, data is stored in a database. In your case, however, all information comes in a long string of text. Each pair of sentences in the text is formatted as follows:
# ````
# <user> is connected to <user1>, ..., <userM>.<user> traveled to <country1>, ..., <countryN>.
# ````
#
#  Here, each sentence shows the user meetings to other users and his/her travel history. For example:
#
# ````
# Usama is connected to Saeed, Aaliya, Mohsin.Usama traveled to Italy, Japan, Korea.
# ````
#
# Note that each sentence will be separated from the next by only a **period (dot).** There will not be a whitespace or new lines between sentences.
#
# Your friend records the information in that string based on user activity on the Website and passes it to you to manage. You can think of every pair of sentences as defining a user's profile.
#
# Consider the various data structures that we have used in class - lists, dictionaries, and combinations of the two (e.g., lists of dictionaries). Choose one that will allow you to manage the data above and implement the procedures below.
#
# You may assume that ***\<user\>*** is a unique identifier for a user. For example, there  can be at most one 'Usama' in the network. Furthermore, connections are asymmetric - if 'Jawad' is connected to 'Babar', it does not necessarily mean that 'Babar' is connected to 'Jawad'.
#
# Your task is to complete the procedures according to the specifications below. You are encouraged to define any additional helper function/procedure(s) that might assist you in accomplishing a task. You are encouraged to test your code using print statements with different data samples.

# %%
# Example string input. Use it to test your code.
example_input="Usama is connected to Saeed, Aaliya, Mohsin.\
Usama traveled to Italy, Japan, Korea.\
Saeed is connected to Sumaira, Zehra, Samar, Marium.\
Saeed traveled to China, Afghanistan.\
Marium is connected to Mohsin, Kashif, Saeed.\
Marium traveled to Japan, USA, Iran.\
Sumaira is connected to Usama, Zehra.\
Sumaira traveled to Japan, Saudi Arabia.\
Aaliya is connected to Mohsin, Bari, Sameera, Kashif.\
Aaliya traveled to India, USA, Malaysia.\
Mohsin is connected to Usama, Bari, Saeed.\
Mohsin traveled to Iran, Indonesia, Afghanistan.\
Bari is connected to Zehra, Usama, Mohsin.\
Bari traveled to Japan, India, China, United Arab Emarites.\
Zehra is connected to Marium, Samar, Saeed.\
Zehra traveled to Russia, Malaysia, Italy.\
Sameera is connected to Bari, Usama, Samar, Kashif.\
Sameera traveled to Afghanistan, New Zealand, Korea, Russia.\
Kashif is connected to Zehra.\
Kashif traveled to Russia, Malaysia.\
Samar is connected to Sumaira, Usama, Aaliya.\
Samar traveled to Saudi Arabia, Indonesia, Iran."

# %%
# create_data_structure(string_input):
#   Parses a block of text (such as the one above) and stores relevant 
#   information into a data structure. You are free to choose and design any 
#   data structure you would like to use to manage the information.
# 
# Arguments: 
#   string_input: block of text containing the network information
#
#   You may assume that for all the test cases we will use, you will be given the information on
#   connections and countries traveled for all users listed on the right-hand side of an
#   'is connected to' statement. For example, we will not use the string 
#   "A is connected to B.A traveled to X, Y, Z.C is connected to A.C traveled to X."
#   as a test case for create_data_structure because the string does not 
#   lists B's connections or traveled countries.
#   
#   The procedure should be able to handle an empty string (the string '') as input, in
#   which case it should return an empty data structure ('network').
# 
# Return:
#   The newly created network data structure
def create_data_structure(string_input):
    x = (((string_input.replace(' is connected to ',', ')).replace(' traveled to ',', '))..split('.'))[:-1]
    for i in range(len(x)):
      x[i] = x[i].split(', ')
    y = {}
    for j in range(len(x), 2):
      y[x[j][0]]=[[],[]]
      y[x[j][0]][0].extend(x[j][1:])
      y[x[j][0]][1].extend(x[j+1][1:])
    return y

net = create_data_structure(example_input)

# %% [markdown]
# Note that the first argument to all procedures below is a 'network' This is the data structure that you created with your create_data_structure procedure though it may be modified as you add new users or new connections. Each procedure below will then modify or extract information from the 'network'.

# %%
def test(got, expected):
    if (got==expected):
        prefix = ' OK '
        print(prefix)
    else:
        prefix = '  X '
        print('%s got: %s\n\n expected: %s\n\n\n' % (prefix, repr((got)), repr((expected))))

# %%
# get_connections(network, user):
#   Returns a list of all the connections that the user has
#
# Arguments: 
#   network: the patients network data structure
#   user:    a string containing the name of the user
# 
# Return: 
#   A list of all connections the user has.
#   - If the user has no connections, return an empty list.
#   - If the user is not in network, return None.
def get_connections(network, user):
	connections = network[0]
	list_of_connections = []
	if IsVertexExists(connections, user):
		for i in connections[user]:
			list_of_connections.append(i[0])
	 	return list_of_connections
	else:
		return None
  
test(get_connections(net, 'Usama'), ['Saeed', 'Aaliya', 'Mohsin'])
test(get_connections(net, 'Saeed'), ['Sumaira', 'Zehra', 'Samar', 'Marium'])
test(get_connections(net, 'Marium'), ['Mohsin', 'Kashif', 'Saeed'])
test(get_connections(net, 'Sumaira'), ['Usama', 'Zehra'])
test(get_connections(net, 'Aaliya'), ['Mohsin', 'Bari', 'Sameera', 'Kashif'])
test(get_connections(net, 'Mohsin'), ['Usama', 'Bari', 'Saeed'])
test(get_connections(net, 'Bari'), ['Zehra', 'Usama', 'Mohsin'])
test(get_connections(net, 'Zehra'), ['Marium', 'Samar', 'Saeed'])
test(get_connections(net, 'Sameera'), ['Bari', 'Usama', 'Samar', 'Kashif'])
test(get_connections(net, 'Kashif'), ['Zehra'])
test(get_connections(net, 'Samar'), ['Sumaira', 'Usama', 'Aaliya'])
test(get_connections(net, 'Aisha'), None)

# %%
# get_countries_traveled(network, user):
#   Returns a list of all the countries a user traveled.
#
# Arguments: 
#   network: the patients' network data structure
#   user:    a string containing the name of the user
# 
# Return: 
#   A list of all countries the user traveled.
#   - If the user traveled no countries, return an empty list.
#   - If the user is not in network, return None.
def get_countries_traveled(network, user):
    countries = network[1]
    list_of_countries = []
    if IsVertexExists(countries, user):
      for i in countries[user]:
        list_of_countries.append(i[0])
      return list_of_connections
    else:
      return None

test(get_countries_traveled(net, 'Usama'), ['Italy', 'Japan', 'Korea'])
test(get_countries_traveled(net, 'Saeed'), ['China', 'Afghanistan'])
test(get_countries_traveled(net, 'Marium'), ['Japan', 'USA', 'Iran'])
test(get_countries_traveled(net, 'Sumaira'), ['Japan', 'Saudi Arabia'])
test(get_countries_traveled(net, 'Aaliya'), ['India', 'USA', 'Malaysia'])
test(get_countries_traveled(net, 'Mohsin'), ['Iran', 'Indonesia', 'Afghanistan'])
test(get_countries_traveled(net, 'Bari'), ['Japan', 'India', 'China', 'United Arab Emarites'])
test(get_countries_traveled(net, 'Zehra'), ['Russia', 'Malaysia', 'Italy'])
test(get_countries_traveled(net, 'Sameera'), ['Afghanistan', 'New Zealand', 'Korea', 'Russia'])
test(get_countries_traveled(net, 'Kashif'), ['Russia', 'Malaysia'])
test(get_countries_traveled(net, 'Samar'), ['Saudi Arabia', 'Indonesia', 'Iran'])
test(get_countries_traveled(net, 'Aisha'), None)

# %%
# ----------------------------------------------------------------------------- 
# add_connection(network, user_A, user_B):
#   Adds a connection from user_A to user_B. Make sure to check that both users 
#   exist in network.
# 
# Arguments: 
#   network: the patients network data structure 
#   user_A:  a string with the name of the user the connection is from
#   user_B:  a string with the name of the user the connection is to
#
# Return: 
#   The updated network with the new connection added.
#   - If a connection already exists from user_A to user_B, the network remains unchanged.
#   - If user_A or user_B is not in network, return None.
def add_connection(network, user_A, user_B):
	if user_A in network and user_B in network:
		if user_B not in network[user_A][0]:
			network[user_A][0].append(user_B)
    return network[user_A][0]
	else:
		return None

# %%
# Sample Testing for User Usama

print(add_connection(net, "Usama", "Saeed"))
print(add_connection(net, "Usama", "Marium"))
print(add_connection(net, "Usama", "Sumaira"))
print(add_connection(net, "Usama", "Aaliya"))
print(add_connection(net, "Usama", "Mohsin"))
print(add_connection(net, "Usama", "Bari"))
print(add_connection(net, "Usama", "Zehra"))
print(add_connection(net, "Usama", "Sameera"))
print(add_connection(net, "Usama", "Kashif"))
print(add_connection(net, "Usama", "Samar"))

# %%
# Sample Testing for User Samar

print(add_connection(net, "Samar", "Usama"))
print(add_connection(net, "Samar", "Saeed"))
print(add_connection(net, "Samar", "Marium"))
print(add_connection(net, "Samar", "Sumaira"))
print(add_connection(net, "Samar", "Aaliya"))
print(add_connection(net, "Samar", "Mohsin"))
print(add_connection(net, "Samar", "Bari"))
print(add_connection(net, "Samar", "Zehra"))
print(add_connection(net, "Samar", "Sameera"))
print(add_connection(net, "Samar", "Kashif"))

# %%
# Corner Cases

print(add_connection(net, "Aisha", "Samar"))
print(add_connection(net, "Kashif", "Arif"))
print(add_connection(net, "ABC", "DEF"))

# %%
# add_new_user(network, user, countries):
#   Creates a new user profile and adds that user to the network, along with
#   any country traveled specified in countries. Assume that the user has no 
#   connections to begin with.
# 
# Arguments:
#   network: the patients network data structure
#   user:    a string containing the name of the user to be added to the network
#   countries:   a list of strings containing the user's traveled countries, e.g.,
#		     ['Indonesia', 'Afghanistan', 'Korea']
#
# Return: 
#   The updated network with the new user and countries traveled added. The new user 
#   should have no connections.
#   - If the user already exists in network, return network *UNCHANGED* (do not change
#     the user's traveled countries)
def add_new_user(network, user, countries):
    if user not in network[0]:
      network[0] = AddVertex(network[0], user)
      network[1] = AddVertex(network[1], user)
      for i in countries:
        network[1] = AddEdge(network[1], user, i, True)
    return network



print(add_new_user(net, "Aisha", ["Pakistan", "Bahrain", "Saudia Arabia"]))
print(add_new_user(net, "Arif", ["Pakistan", "Dubai", "Belgium"]))
print(add_new_user(net, "Arif", ["India", "Dubai", "America"]))
print(add_new_user(net, "Rayyan", ["India", "Dubai", "America"]))
print(add_new_user(net, "Samar", ["India", "Dubai", "America"]))

# %%
# get_secondary_connections(network, user):
#   Finds all the secondary connections (i.e., connections of connections) of a
#   given user.
# 
# Arguments: 
#   network: the patients network data structure
#   user:    a string containing the name of the user
#
# Return: 
#   A list containing the secondary connections (connections of connections).
#   - If the user is not in the network, return None.
#   - If a user has no primary connections to begin with, return an empty list.
# 
# NOTE: 
#   It is OK if a user's list of secondary connections includes the user 
#   himself/herself. It is also OK if the list contains a user's primary 
#   connection that is a secondary connection as well.
def get_secondary_connections(network, user):
	a = []
 	for i in (Adjacent(network[0], user)):
		 b = Adjacent(connections, i)
	for j in b:
		if j not in a:
			a.append(j)
	return a

 

test(sorted(get_secondary_connections(net, 'Usama')), sorted(list(set(['Sumaira', 'Zehra', 'Samar', 'Marium', 'Mohsin', 'Bari', 'Sameera', 'Kashif', 'Usama', 'Bari', 'Saeed']))))
test(sorted(get_secondary_connections(net, 'Saeed')), sorted(list(set(['Usama', 'Zehra', 'Marium', 'Samar', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Kashif', 'Saeed']))))
test(sorted(get_secondary_connections(net, 'Marium')), sorted(list(set(['Usama', 'Bari', 'Saeed', 'Zehra', 'Sumaira', 'Zehra', 'Samar', 'Marium']))))
test(sorted(get_secondary_connections(net, 'Sumaira')), sorted(list(set(['Saeed', 'Aaliya', 'Mohsin', 'Marium', 'Samar', 'Saeed']))))
test(sorted(get_secondary_connections(net, 'Aaliya')), sorted(list(set(['Usama', 'Bari', 'Saeed', 'Zehra', 'Usama', 'Mohsin', 'Bari', 'Usama', 'Samar', 'Kashif', 'Zehra']))))
test(sorted(get_secondary_connections(net, 'Mohsin')), sorted(list(set(['Saeed', 'Aaliya', 'Mohsin', 'Zehra', 'Usama', 'Mohsin', 'Sumaira', 'Zehra', 'Samar', 'Marium']))))
test(sorted(get_secondary_connections(net, 'Bari')), sorted(list(set(['Marium', 'Samar', 'Saeed', 'Saeed', 'Aaliya', 'Mohsin', 'Usama', 'Bari', 'Saeed']))))
test(sorted(get_secondary_connections(net, 'Zehra')), sorted(list(set(['Mohsin', 'Kashif', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sumaira', 'Zehra', 'Samar', 'Marium']))))
test(sorted(get_secondary_connections(net, 'Sameera')), sorted(list(set(['Zehra', 'Usama', 'Mohsin', 'Saeed', 'Aaliya', 'Mohsin', 'Sumaira', 'Usama', 'Aaliya', 'Zehra']))))
test(sorted(get_secondary_connections(net, 'Kashif')), sorted(list(set(['Marium', 'Samar', 'Saeed']))))
test(sorted(get_secondary_connections(net, 'Samar')), sorted(list(set(['Usama', 'Zehra', 'Saeed', 'Aaliya', 'Mohsin', 'Mohsin', 'Bari', 'Sameera', 'Kashif']))))

# %%
# count_common_connections(network, user_A, user_B):
#   Finds the number of people that user_A and user_B have in common.
#  
# Arguments: 
#   network: the patients network data structure
#   user_A:  a string containing the name of user_A
#   user_B:  a string containing the name of user_B
#
# Return:
#   The number of connections in common (as an integer).
#   - If user_A or user_B is not in network, return False.
def count_common_connections(network, user_A, user_B):
    if IsVertexExists(network[0], user_A) and IsVertexExists(network[0], user_B):
      return len(MutualFriends(network[0], user_A, user_B))
    else:
      return False

test(count_common_connections(net, "Usama", "Saeed"), 0)
test(count_common_connections(net, "Saeed", "Usama"), 0)

test(count_common_connections(net, "Usama", "Marium"), 2)
test(count_common_connections(net, "Marium", "Usama"), 2)

test(count_common_connections(net, "Usama", "Sumaira"), 0)
test(count_common_connections(net, "Sumaira", "Usama"), 0)

test(count_common_connections(net, "Usama", "Aaliya"), 1)
test(count_common_connections(net, "Aaliya", "Usama"), 1)

test(count_common_connections(net, "Usama", "Mohsin"), 1)
test(count_common_connections(net, "Mohsin", "Usama"), 1)

test(count_common_connections(net, "Usama", "Bari"), 1)
test(count_common_connections(net, "Bari", "Usama"), 1)

test(count_common_connections(net, "Usama", "Zehra"), 1)
test(count_common_connections(net, "Zehra", "Usama"), 1)

test(count_common_connections(net, "Usama", "Sameera"), 0)
test(count_common_connections(net, "Sameera", "Usama"), 0)


test(count_common_connections(net, "Usama", "Kashif"), 0)
test(count_common_connections(net, "Kashif", "Usama"), 0)

test(count_common_connections(net, "Usama", "Samar"), 1)
test(count_common_connections(net, "Samar", "Usama"), 1)

test(count_common_connections(net, "Saeed", "Marium"), 0)
test(count_common_connections(net, "Marium", "Saeed"), 0)

test(count_common_connections(net, "Saeed", "Sumaira"), 1)
test(count_common_connections(net, "Sumaira", "Saeed"), 1)

test(count_common_connections(net, "Saeed", "Aaliya"), 0)
test(count_common_connections(net, "Aaliya", "Saeed"), 0)

test(count_common_connections(net, "Saeed", "Mohsin"), 0)
test(count_common_connections(net, "Mohsin", "Saeed"), 0)

test(count_common_connections(net, "Saeed", "Bari"), 1)
test(count_common_connections(net, "Bari", "Saeed"), 1)

test(count_common_connections(net, "Saeed", "Zehra"), 2)
test(count_common_connections(net, "Zehra", "Saeed"), 2)

test(count_common_connections(net, "Saeed", "Sameera"), 1)
test(count_common_connections(net, "Sameera", "Saeed"), 1)

test(count_common_connections(net, "Saeed", "Kashif"), 1)
test(count_common_connections(net, "Kashif", "Saeed"), 1)

test(count_common_connections(net, "Saeed", "Samar"), 1)
test(count_common_connections(net, "Samar", "Saeed"), 1)

test(count_common_connections(net, "Marium", "Sumaira"), 0)
test(count_common_connections(net, "Sumaira", "Marium"), 0)

test(count_common_connections(net, "Marium", "Aaliya"), 2)
test(count_common_connections(net, "Aaliya", "Marium"), 2)

test(count_common_connections(net, "Marium", "Mohsin"), 1)
test(count_common_connections(net, "Mohsin", "Marium"), 1)

test(count_common_connections(net, "Marium", "Bari"), 1)
test(count_common_connections(net, "Bari", "Marium"), 1)

test(count_common_connections(net, "Marium", "Zehra"), 1)
test(count_common_connections(net, "Zehra", "Marium"), 1)

test(count_common_connections(net, "Marium", "Sameera"), 1)
test(count_common_connections(net, "Sameera", "Marium"), 1)

test(count_common_connections(net, "Marium", "Kashif"), 0)
test(count_common_connections(net, "Kashif", "Marium"), 0)

test(count_common_connections(net, "Marium", "Samar"), 0)
test(count_common_connections(net, "Samar", "Marium"), 0)

test(count_common_connections(net, "Sumaira", "Aaliya"), 0)
test(count_common_connections(net, "Aaliya", "Sumaira"), 0)

test(count_common_connections(net, "Sumaira", "Mohsin"), 1)
test(count_common_connections(net, "Mohsin", "Sumaira"), 1)

test(count_common_connections(net, "Sumaira", "Bari"), 2)
test(count_common_connections(net, "Bari", "Sumaira"), 2)

test(count_common_connections(net, "Sumaira", "Zehra"), 0)
test(count_common_connections(net, "Zehra", "Sumaira"), 0)

test(count_common_connections(net, "Sumaira", "Sameera"), 1)
test(count_common_connections(net, "Sameera", "Sumaira"), 1)

test(count_common_connections(net, "Sumaira", "Kashif"), 1)
test(count_common_connections(net, "Kashif", "Sumaira"), 1)

test(count_common_connections(net, "Sumaira", "Samar"), 1)
test(count_common_connections(net, "Samar", "Sumaira"), 1)

test(count_common_connections(net, "Aaliya", "Mohsin"), 1)
test(count_common_connections(net, "Mohsin", "Aaliya"), 1)

test(count_common_connections(net, "Aaliya", "Bari"), 1)
test(count_common_connections(net, "Bari", "Aaliya"), 1)

test(count_common_connections(net, "Aaliya", "Zehra"), 0)
test(count_common_connections(net, "Zehra", "Aaliya"), 0)

test(count_common_connections(net, "Aaliya", "Sameera"), 2)
test(count_common_connections(net, "Sameera", "Aaliya"), 2)

test(count_common_connections(net, "Aaliya", "Kashif"), 0)
test(count_common_connections(net, "Kashif", "Aaliya"), 0)

test(count_common_connections(net, "Aaliya", "Samar"), 0)
test(count_common_connections(net, "Samar", "Aaliya"), 0)

test(count_common_connections(net, "Mohsin", "Bari"), 1)
test(count_common_connections(net, "Bari", "Mohsin"), 1)

test(count_common_connections(net, "Mohsin", "Zehra"), 1)
test(count_common_connections(net, "Zehra", "Mohsin"), 1)

test(count_common_connections(net, "Mohsin", "Sameera"), 2)
test(count_common_connections(net, "Sameera", "Mohsin"), 2)

test(count_common_connections(net, "Mohsin", "Kashif"), 0)
test(count_common_connections(net, "Kashif", "Mohsin"), 0)

test(count_common_connections(net, "Mohsin", "Samar"), 1)
test(count_common_connections(net, "Samar", "Mohsin"), 1)

test(count_common_connections(net, "Bari", "Zehra"), 0)
test(count_common_connections(net, "Zehra", "Bari"), 0)

test(count_common_connections(net, "Bari", "Sameera"), 1)
test(count_common_connections(net, "Sameera", "Bari"), 1)

test(count_common_connections(net, "Bari", "Kashif"), 1)
test(count_common_connections(net, "Kashif", "Bari"), 1)

test(count_common_connections(net, "Bari", "Samar"), 1)
test(count_common_connections(net, "Samar", "Bari"), 1)

test(count_common_connections(net, "Zehra", "Kashif"), 0)
test(count_common_connections(net, "Kashif", "Zehra"), 0)

test(count_common_connections(net, "Zehra", "Samar"), 0)
test(count_common_connections(net, "Samar", "Zehra"), 0)

test(count_common_connections(net, "Sameera", "Zehra"), 1)
test(count_common_connections(net, "Zehra", "Sameera"), 1)


test(count_common_connections(net, "Sameera", "Kashif"), 0)
test(count_common_connections(net, "Kashif", "Sameera"), 0)

test(count_common_connections(net, "Sameera", "Samar"), 1)
test(count_common_connections(net, "Samar", "Sameera"), 1)


test(count_common_connections(net, "Kashif", "Samar"), 0)
test(count_common_connections(net, "Samar", "Kashif"), 0)

test(count_common_connections(net, "Aisha", "Samar"), False)
test(count_common_connections(net, "Kashif", "Arif"), False)
test(count_common_connections(net, "ABC", "DEF"), False)

# %%
# find_path_to_patient(network, user_A, user_B):
#   Finds a path  from user_A to user_B. It has to be an existing
#   path but it DOES NOT have to be the shortest path.
#   
# Arguments:
#   network: The network you created with create_data_structure. 
#   user_A:  String holding the starting username ("Abe")
#   user_B:  String holding the ending username ("Zed")
# 
# Return:
#   A list showing the path from user_A to user_B.
#   - If such a path does not exist, return None.
#   - If user_A or user_B is not in network, return None.
#
# Sample output:
#   >>> print find_path_to_patient(network, "Abe", "Zed")
#   >>> ['Abe', 'Gel', 'Sam', 'Zed']
#   This implies that Abe is connected with Gel, who is connected with Sam, 
#   who is connected with Zed.
# 
# NOTE:
#   You must solve this problem using recursion!
# 
# Hints: 
# - Be careful how you handle connection loops, for example, A is connected to B. 
#   B is connected to C. C is connected to B. Make sure your code terminates in 
#   that case.
# - If you are comfortable with default parameters, you might consider using one 
#   in this procedure to keep track of nodes already visited in your search. You 
#   may safely add default parameters since all calls used in the grading script 
#   will only include the arguments network, user_A, and user_B.
def find_path_to_patient(network, user_A, user_B):
	# your RECURSIVE solution here!
	if user_A not in network or user_B not in network:
		return None
	a = []
	if IsVertexExists(network[0], user_A) and IsVertexExists(network[0], user_B):
		if len(network[0][user_A]) != 0:
			for i in network[0][user_A]:
				a.append(i[0])
			while len(a) > 0:

# %%
# Don't modify

usamatosaeed = [['Usama', 'Saeed'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Usama', 'Mohsin', 'Saeed']]   
saeedtousama = [['Saeed', 'Sumaira', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Saeed', 'Samar', 'Sumaira', 'Usama'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 
'Samar', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Marium', 'Mohsin', 'Usama'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama']]

usamatomarium = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Usama', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 
'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 
'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Usama', 'Mohsin', 'Saeed', 'Marium']]

mariumtousama = [['Marium', 'Mohsin', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Mohsin', 'Bari', 'Usama'], 
['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 
'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Marium', 'Kashif', 
'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 
'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama']]

usamatosumaira = [['Usama', 'Saeed', 'Sumaira'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 
'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 
'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira']]

sumairatousama = [['Sumaira', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Sumaira', 
'Zehra', 'Samar', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama']]

usamatoaaliya = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Saeed', 'Samar', 'Aaliya'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Aaliya'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya']]

aaliyatousama = [['Aaliya', 'Mohsin', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 
'Zehra', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 
'Saeed', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Bari', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Usama'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Aaliya', 'Sameera', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 
'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Aaliya', 'Kashif', 
'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama']]

usamatomohsin = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Marium', 'Mohsin'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Usama', 'Aaliya', 'Mohsin'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 
'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Usama', 'Mohsin']]

mohsintousama = [['Mohsin', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Mohsin', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Mohsin', 'Saeed', 'Samar', 'Usama'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama']]

usamatobari = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Usama', 'Aaliya', 'Bari'], ['Usama', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Usama', 'Mohsin', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Usama', 'Mohsin', 
'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari']]

baritousama = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Samar', 'Usama'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Bari', 'Usama'], ['Bari', 'Mohsin', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama']]

usamatozehra = [['Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Usama', 'Saeed', 'Zehra'], ['Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Usama', 'Aaliya', 'Bari', 'Zehra'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Usama', 'Mohsin', 'Bari', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra']]

zehratousama = [['Zehra', 'Marium', 'Mohsin', 'Usama'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Zehra', 
'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 
'Usama'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Zehra', 'Samar', 'Sumaira', 'Usama'], ['Zehra', 'Samar', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama']]

usamatosameera = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Saeed', 
'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 
'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera']]

sameeratousama = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 
'Usama'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Bari', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Usama'], ['Sameera', 'Bari', 
'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 
'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Sameera', 'Usama'], ['Sameera', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Samar', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 
'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 
'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 
'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama']]

usamatokashif = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 
'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif']]

kashiftousama = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama']]

usamatosamar = [['Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Usama', 'Saeed', 'Zehra', 'Samar'], ['Usama', 'Saeed', 'Samar'], ['Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Usama', 'Mohsin', 'Saeed', 'Samar'], ['Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar']]

samartousama = [['Samar', 'Sumaira', 'Usama'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Samar', 'Usama'], ['Samar', 'Aaliya', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Samar', 
'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], 
['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 
'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama']]

saeedtomarium = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Saeed', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], 
['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], 
['Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 
'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Saeed', 'Marium']]

mariumtosaeed = [['Marium', 'Mohsin', 'Usama', 'Saeed'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Marium', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 
'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Marium', 'Kashif', 'Zehra', 'Saeed'], ['Marium', 'Saeed']]

saeedtosumaira = [['Saeed', 'Sumaira'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 
'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira']]

sumairatosaeed = [['Sumaira', 'Usama', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 
'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 
'Usama', 'Saeed'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Sumaira', 'Zehra', 'Saeed']]

saeedtoaaliya = [['Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Saeed', 'Samar', 'Usama', 'Aaliya'], ['Saeed', 'Samar', 'Aaliya'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya']]

aaliyatosaeed = [['Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Aaliya', 'Mohsin', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Aaliya', 'Bari', 'Usama', 'Saeed'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 
'Samar', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Aaliya', 'Sameera', 'Samar', 
'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed']]

saeedtomohsin = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Usama', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 
'Sameera', 'Usama', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Saeed', 'Marium', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin']]

mohsintosaeed = [['Mohsin', 'Usama', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 
'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Mohsin', 'Saeed']]

saeedtobari = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], 
['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Samar', 
'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Aaliya', 'Bari'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Marium', 
'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Marium', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 
'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari']]

baritosaeed = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Bari', 'Zehra', 'Saeed'], ['Bari', 'Usama', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 
'Saeed'], ['Bari', 'Usama', 'Mohsin', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 
'Saeed'], ['Bari', 'Mohsin', 'Saeed']]

saeedtozehra = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Sumaira', 'Zehra'], ['Saeed', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 
'Bari', 'Zehra'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 
'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Saeed', 'Marium', 'Kashif', 'Zehra']]

zehratosaeed = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Zehra', 'Marium', 'Saeed'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Zehra', 'Saeed']]

saeedtosameera = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera']]

sameeratosaeed = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Usama', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sameera', 
'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 
'Marium', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Sameera', 'Kashif', 'Zehra', 'Saeed']]

saeedtokashif = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 
'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Zehra', 'Marium', 
'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 
'Kashif'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 
'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 
'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Saeed', 'Marium', 'Kashif']]

kashiftosaeed = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Marium', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 
'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Kashif', 'Zehra', 'Saeed']]

saeedtosamar = [['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Zehra', 'Samar'], ['Saeed', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 
'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar']]  

samartosaeed = [['Samar', 'Sumaira', 'Usama', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 
'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], 
['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 
'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 
'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Sumaira', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 
'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Usama', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed'], ['Samar', 
'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed']]

mariumtosumaira = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 
'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 
'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 
'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Marium', 'Saeed', 'Sumaira'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Marium', 'Saeed', 'Samar', 'Sumaira']]

sumairatomarium = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 
'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sumaira', 'Zehra', 'Saeed', 'Marium']]

mariumtoaaliya = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 
'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 
'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Marium', 'Saeed', 'Samar', 'Aaliya']]

aaliyatomarium = [['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 
'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 
'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium']]

mariumtomohsin = [['Marium', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], 
['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], 
['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 
'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 
'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], 
['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 
'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 
'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin']]

mohsintomarium = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Saeed', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 
'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 
'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], 
['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 
'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 
'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Mohsin', 'Saeed', 'Marium']]

mariumtobari = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 
'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 
'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 
'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 
'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari']]

baritomarium = [['Bari', 'Zehra', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Usama', 
'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 
'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Saeed', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Mohsin', 
'Saeed', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 
'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Bari', 'Mohsin', 'Saeed', 'Marium']]

mariumtozehra = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 
'Zehra'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 
'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Sumaira', 'Zehra'], ['Marium', 'Saeed', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 
'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 
'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra']]

zehratomarium = [['Zehra', 'Marium'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 
'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 
'Bari', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 
'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], 
['Zehra', 'Saeed', 'Marium']]

mariumtosameera = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], 
['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 
'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera']]

sameeratomarium = [['Sameera', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 
'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 
'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 
'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 
'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 
'Zehra', 'Marium'], ['Sameera', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 
'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 
'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 
'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 
'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 
'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 
'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Usama', 
'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 
'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 
'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 
'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium']]

mariumtokashif = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 
'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 
'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], 
['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Marium', 'Saeed', 
'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif']]

kashiftomarium = [['Kashif', 'Zehra', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 
'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 
'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Kashif', 'Zehra', 'Saeed', 'Marium']]

mariumtosamar = [['Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], 
['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Marium', 'Mohsin', 'Saeed', 'Samar'], ['Marium', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Marium', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], 
['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Zehra', 'Samar'], ['Marium', 'Saeed', 'Samar']]

samartomarium = [['Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 
'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium'], 
['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium']]

sumairatoaaliya = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Aaliya'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 
'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya']]

aaliyatosumaira = [['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 
'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], 
['Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], 
['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 
'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira']]

sumairatomohsin = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 
'Aaliya', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 
'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], 
['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 
'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin']]

mohsintosumaira =[['Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 
'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 
'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 
'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Saeed', 'Sumaira'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira']]

sumairatobari = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 
'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 
'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sumaira', 
'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari']]

baritosumaira = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 
'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Zehra', 'Saeed', 'Marium', 
'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 
'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira']]  

sumairatozehra = [['Sumaira', 'Usama', 'Saeed', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sumaira', 'Zehra']]

zehratosumaira = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Zehra', 'Samar', 'Sumaira'], ['Zehra', 'Samar', 'Usama', 'Saeed', 
'Sumaira'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Zehra', 'Saeed', 'Sumaira'], ['Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira']]

sumairatosameera = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 
'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 
'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera']]

sameeratosumaira = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 
'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 
'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 
'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Samar', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 
'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira']]

sumairatokashif = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 
'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Saeed', 
'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 
'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 
'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif']]

kashiftosumaira = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 
'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 
'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], 
['Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira']]

sumairatosamar = [['Sumaira', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 
'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], 
['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sumaira', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sumaira', 'Zehra', 'Samar'], ['Sumaira', 'Zehra', 'Saeed', 'Samar'], ['Sumaira', 'Zehra', 'Saeed', 
'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar']]

samartosumaira = [['Samar', 'Sumaira'], ['Samar', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 
'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 
'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira']]

aaliyatomohsin = [['Aaliya', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 
'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 
'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Aaliya', 'Bari', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 
'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin']]

mohsintoaaliya = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Usama', 'Aaliya'], 
['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], 
['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya']]

aaliyatobari = [['Aaliya', 'Mohsin', 'Bari'], ['Aaliya', 'Bari'], ['Aaliya', 'Sameera', 'Bari'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 
'Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari']]

baritoaaliya = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Aaliya'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya']]

aaliyatozehra = [['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Bari', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 
'Saeed', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 
'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 
'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], 
['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Aaliya', 'Kashif', 'Zehra']]

zehratoaaliya = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Samar', 'Usama', 'Aaliya'], ['Zehra', 'Samar', 'Aaliya'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya']]

aaliyatosameera = [['Aaliya', 'Sameera']]

sameeratoaaliya = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 
'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], 
['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 
'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 
'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Saeed', 'Marium', 
'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Sameera', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya']]

aaliyatokashif = [['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 
'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 
'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 
'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 
'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 
'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], 
['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 
'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Aaliya', 'Sameera', 'Kashif'], ['Aaliya', 'Kashif']]

kashiftoaaliya = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Samar', 'Aaliya'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya']]

aaliyatosamar = [['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 
'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Samar'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar']]

samartoaaliya = [['Samar', 'Sumaira', 'Usama', 'Aaliya'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya'], ['Samar', 'Usama', 'Aaliya'], ['Samar', 'Aaliya']]

mohsintobari = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Bari'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 
'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari']]

baritomohsin = [['Bari', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Bari', 
'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Bari', 'Usama', 'Mohsin'], ['Bari', 'Mohsin']]

mohsintozehra = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 
'Zehra'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Bari', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 
'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Mohsin', 'Saeed', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 
'Bari', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra']]

zehratomohsin = [['Zehra', 'Marium', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Samar', 'Usama', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 
'Usama', 'Aaliya', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 
'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Zehra', 'Saeed', 'Marium', 'Mohsin']]

mohsintosameera = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 
'Sameera'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera']]

sameeratomohsin = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Bari', 'Usama', 'Mohsin'], ['Sameera', 'Bari', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 
'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 
'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 
'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 
'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], 
['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin']]

mohsintokashif = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 
'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 
'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 
'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Bari', 
'Usama', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 
'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 
'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Mohsin', 'Saeed', 'Marium', 'Kashif']]

kashiftomohsin = [['Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 
'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Kashif', 
'Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 
'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin']]

mohsintosamar = [['Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Zehra', 'Samar'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Samar'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Mohsin', 'Saeed', 'Samar'], ['Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar']]

samartomohsin = [['Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 
'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Sumaira', 'Zehra', 
'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 
'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Bari', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 
'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 
'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 
'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin']]

baritozehra = [['Bari', 'Zehra'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Saeed', 'Zehra'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 
'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Bari', 
'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra']]

zehratobari = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 
'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 
'Aaliya', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Samar', 'Aaliya', 'Bari'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], 
['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari']] 

baritosameera = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], 
['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Zehra', 
'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera']]

sameeratobari = [['Sameera', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 
'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 
'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 
'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 
'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari']]

baritokashif = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 
'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 
'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 
'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 
'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 
'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 
'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 
'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 
'Marium', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif']]

kashiftobari = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 
'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], 
['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], 
['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari']]

baritosamar = [['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Bari', 'Zehra', 'Samar'], ['Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Zehra', 'Saeed', 'Samar'], ['Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 
'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Usama', 
'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Samar'], ['Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar']]

samartobari = [['Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Bari'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 
'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 
'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Mohsin', 'Bari'], ['Samar', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari']]

zehratokashif = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 
'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Zehra', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], 
['Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 
'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Zehra', 'Saeed', 'Marium', 'Kashif']]

kashiftozehra = [['Kashif', 'Zehra']]

zehratosamar = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Zehra', 'Marium', 'Saeed', 'Samar'], ['Zehra', 'Samar'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Zehra', 'Saeed', 'Samar'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar']]

samartozehra = [['Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Sumaira', 'Zehra'], ['Samar', 
'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], 
['Samar', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 
'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 
'Zehra'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 
'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 
'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Sameera', 'Kashif', 'Zehra'], ['Samar', 'Aaliya', 'Kashif', 'Zehra']]

sameeratozehra = [['Sameera', 'Bari', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 
'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 
'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 
'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra'], ['Sameera', 'Samar', 'Aaliya', 'Kashif', 'Zehra'], ['Sameera', 'Kashif', 'Zehra']]

zehratosameera = [['Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera']]

sameeratokashif = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 
'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 
'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 
'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 
'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Aaliya', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 
'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 
'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Sameera', 'Samar', 'Aaliya', 'Kashif'], ['Sameera', 'Kashif']]

kashiftosameera = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Samar', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Saeed', 'Samar', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 
'Zehra', 'Saeed', 'Samar', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera']]

sameeratosamar = [['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Aaliya', 'Kashif', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 
'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Samar'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif', 
'Zehra', 'Samar'], ['Sameera', 'Samar'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Sameera', 'Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Sameera', 'Kashif', 'Zehra', 'Samar'], ['Sameera', 'Kashif', 'Zehra', 'Saeed', 'Samar']]  

samartosameera = [['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera'], ['Samar', 'Usama', 'Aaliya', 'Sameera'], ['Samar', 'Aaliya', 'Sameera']]

kashiftosamar = [['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Saeed', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Mohsin', 'Saeed', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Kashif', 'Zehra', 'Marium', 'Saeed', 'Samar'], ['Kashif', 'Zehra', 'Samar'], ['Kashif', 'Zehra', 'Saeed', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Kashif', 'Zehra', 'Saeed', 'Samar'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Samar'], ['Kashif', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Samar']]

samartokashif = [['Samar', 'Sumaira', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 
'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Aaliya', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 
'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Usama', 'Aaliya', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Mohsin', 'Bari', 'Usama', 'Aaliya', 'Kashif'], ['Samar', 'Sumaira', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 
'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Usama', 'Aaliya', 'Kashif'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 
'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Bari', 'Usama', 
'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Marium', 
'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Zehra', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 
'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Bari', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Bari', 'Zehra', 
'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Sumaira', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Zehra', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Usama', 'Mohsin', 'Saeed', 'Marium', 'Kashif'], ['Samar', 'Aaliya', 'Sameera', 'Kashif'], ['Samar', 'Aaliya', 'Kashif']]

# %%
def test2(got, expected):
    if got in expected:
        prefix = ' OK '
        print(prefix)
    else:
        prefix = '  X '
        print('%s got: %s\n\n expected: %s\n\n\n' % (prefix, repr(got), repr(expected)))

# %%
test2(find_path_to_patient(net, "Usama", "Saeed"), usamatosaeed) 
test2(find_path_to_patient(net, "Saeed", "Usama"), saeedtousama)

test2(find_path_to_patient(net, "Usama", "Marium"), usamatomarium)
test2(find_path_to_patient(net, "Marium", "Usama"), mariumtousama)

test2(find_path_to_patient(net, "Usama", "Sumaira"), usamatosumaira)
test2(find_path_to_patient(net, "Sumaira", "Usama"), sumairatousama)

test2(find_path_to_patient(net, "Usama", "Aaliya"), usamatoaaliya)
test2(find_path_to_patient(net, "Aaliya", "Usama"), aaliyatousama)

test2(find_path_to_patient(net, "Usama", "Mohsin"), usamatomohsin)
test2(find_path_to_patient(net, "Mohsin", "Usama"), mohsintousama)

test2(find_path_to_patient(net, "Usama", "Bari"), usamatobari)
test2(find_path_to_patient(net, "Bari", "Usama"), baritousama)

test2(find_path_to_patient(net, "Usama", "Zehra"), usamatozehra)
test2(find_path_to_patient(net, "Zehra", "Usama"), zehratousama)

test2(find_path_to_patient(net, "Usama", "Sameera"), usamatosameera)
test2(find_path_to_patient(net, "Sameera", "Usama"), sameeratousama)

test2(find_path_to_patient(net, "Usama", "Kashif"), usamatokashif)
test2(find_path_to_patient(net, "Kashif", "Usama"), kashiftousama)

test2(find_path_to_patient(net, "Usama", "Samar"), usamatosamar)
test2(find_path_to_patient(net, "Samar", "Usama"), samartousama)

test2(find_path_to_patient(net, "Saeed", "Marium"), saeedtomarium)
test2(find_path_to_patient(net, "Marium", "Saeed"), mariumtosaeed)

test2(find_path_to_patient(net, "Saeed", "Sumaira"), saeedtosumaira)
test2(find_path_to_patient(net, "Sumaira", "Saeed"), sumairatosaeed)

test2(find_path_to_patient(net, "Saeed", "Aaliya"), saeedtoaaliya)
test2(find_path_to_patient(net, "Aaliya", "Saeed"), aaliyatosaeed)

test2(find_path_to_patient(net, "Saeed", "Mohsin"), saeedtomohsin)
test2(find_path_to_patient(net, "Mohsin", "Saeed"), mohsintosaeed)

test2(find_path_to_patient(net, "Saeed", "Bari"), saeedtobari)
test2(find_path_to_patient(net, "Bari", "Saeed"), baritosaeed)

test2(find_path_to_patient(net, "Saeed", "Zehra"), saeedtozehra)
test2(find_path_to_patient(net, "Zehra", "Saeed"), zehratosaeed)

test2(find_path_to_patient(net, "Saeed", "Sameera"), saeedtosameera)
test2(find_path_to_patient(net, "Sameera", "Saeed"), sameeratosaeed)

test2(find_path_to_patient(net, "Saeed", "Kashif"), saeedtokashif)
test2(find_path_to_patient(net, "Kashif", "Saeed"), kashiftosaeed)

test2(find_path_to_patient(net, "Saeed", "Samar"), saeedtosamar)
test2(find_path_to_patient(net, "Samar", "Saeed"), samartosaeed)

test2(find_path_to_patient(net, "Marium", "Sumaira"), mariumtosumaira)
test2(find_path_to_patient(net, "Sumaira", "Marium"), sumairatomarium)

test2(find_path_to_patient(net, "Marium", "Aaliya"), mariumtoaaliya)
test2(find_path_to_patient(net, "Aaliya", "Marium"), aaliyatomarium)

test2(find_path_to_patient(net, "Marium", "Mohsin"), mariumtomohsin)
test2(find_path_to_patient(net, "Mohsin", "Marium"), mohsintomarium)

test2(find_path_to_patient(net, "Marium", "Bari"), mariumtobari)
test2(find_path_to_patient(net, "Bari", "Marium"), baritomarium)

test2(find_path_to_patient(net, "Marium", "Zehra"), mariumtozehra)
test2(find_path_to_patient(net, "Zehra", "Marium"), zehratomarium)

test2(find_path_to_patient(net, "Marium", "Sameera"), mariumtosameera)
test2(find_path_to_patient(net, "Sameera", "Marium"), sameeratomarium)

test2(find_path_to_patient(net, "Marium", "Kashif"), mariumtokashif)
test2(find_path_to_patient(net, "Kashif", "Marium"), kashiftomarium)

test2(find_path_to_patient(net, "Marium", "Samar"), mariumtosamar)
test2(find_path_to_patient(net, "Samar", "Marium"), samartomarium)

test2(find_path_to_patient(net, "Sumaira", "Aaliya"), sumairatoaaliya)
test2(find_path_to_patient(net, "Aaliya", "Sumaira"), aaliyatosumaira)

test2(find_path_to_patient(net, "Sumaira", "Mohsin"), sumairatomohsin)
test2(find_path_to_patient(net, "Mohsin", "Sumaira"), mohsintosumaira)

test2(find_path_to_patient(net, "Sumaira", "Bari"), sumairatobari)
test2(find_path_to_patient(net, "Bari", "Sumaira"), baritosumaira)

test2(find_path_to_patient(net, "Sumaira", "Zehra"), sumairatozehra)
test2(find_path_to_patient(net, "Zehra", "Sumaira"), zehratosumaira)

test2(find_path_to_patient(net, "Sumaira", "Sameera"), sumairatosameera)
test2(find_path_to_patient(net, "Sameera", "Sumaira"), sameeratosumaira)

test2(find_path_to_patient(net, "Sumaira", "Kashif"), sumairatokashif)
test2(find_path_to_patient(net, "Kashif", "Sumaira"), kashiftosumaira)

test2(find_path_to_patient(net, "Sumaira", "Samar"), sumairatosamar)
test2(find_path_to_patient(net, "Samar", "Sumaira"), samartosumaira)

test2(find_path_to_patient(net, "Aaliya", "Mohsin"), aaliyatomohsin)
test2(find_path_to_patient(net, "Mohsin", "Aaliya"), mohsintoaaliya)

test2(find_path_to_patient(net, "Aaliya", "Bari"), aaliyatobari)
test2(find_path_to_patient(net, "Bari", "Aaliya"), baritoaaliya)

test2(find_path_to_patient(net, "Aaliya", "Zehra"), aaliyatozehra)
test2(find_path_to_patient(net, "Zehra", "Aaliya"), zehratoaaliya)

test2(find_path_to_patient(net, "Aaliya", "Sameera"), aaliyatosameera)
test2(find_path_to_patient(net, "Sameera", "Aaliya"), sameeratoaaliya)

test2(find_path_to_patient(net, "Aaliya", "Kashif"), aaliyatokashif)
test2(find_path_to_patient(net, "Kashif", "Aaliya"), kashiftoaaliya)

test2(find_path_to_patient(net, "Aaliya", "Samar"), aaliyatosamar)
test2(find_path_to_patient(net, "Samar", "Aaliya"), samartoaaliya)

test2(find_path_to_patient(net, "Mohsin", "Bari"), mohsintobari)
test2(find_path_to_patient(net, "Bari", "Mohsin"), baritomohsin)

test2(find_path_to_patient(net, "Mohsin", "Zehra"), mohsintozehra)
test2(find_path_to_patient(net, "Zehra", "Mohsin"), zehratomohsin)

test2(find_path_to_patient(net, "Mohsin", "Sameera"), mohsintosameera)
test2(find_path_to_patient(net, "Sameera", "Mohsin"), sameeratomohsin)

test2(find_path_to_patient(net, "Mohsin", "Kashif"), mohsintokashif)
test2(find_path_to_patient(net, "Kashif", "Mohsin"), kashiftomohsin)

test2(find_path_to_patient(net, "Mohsin", "Samar"), mohsintosamar)
test2(find_path_to_patient(net, "Samar", "Mohsin"), samartomohsin)

test2(find_path_to_patient(net, "Bari", "Zehra"), baritozehra)
test2(find_path_to_patient(net, "Zehra", "Bari"), zehratobari)

test2(find_path_to_patient(net, "Bari", "Sameera"), baritosameera)
test2(find_path_to_patient(net, "Sameera", "Bari"), sameeratobari)

test2(find_path_to_patient(net, "Bari", "Kashif"), baritokashif)
test2(find_path_to_patient(net, "Kashif", "Bari"), kashiftobari)

test2(find_path_to_patient(net, "Bari", "Samar"), baritosamar)
test2(find_path_to_patient(net, "Samar", "Bari"), samartobari)

test2(find_path_to_patient(net, "Zehra", "Kashif"), zehratokashif)
test2(find_path_to_patient(net, "Kashif", "Zehra"), kashiftozehra)

test2(find_path_to_patient(net, "Zehra", "Samar"), zehratosamar)
test2(find_path_to_patient(net, "Samar", "Zehra"), samartozehra)

test2(find_path_to_patient(net, "Sameera", "Zehra"), sameeratozehra)
test2(find_path_to_patient(net, "Zehra", "Sameera"), zehratosameera)

test2(find_path_to_patient(net, "Sameera", "Kashif"), sameeratokashif)
test2(find_path_to_patient(net, "Kashif", "Sameera"), kashiftosameera)

test2(find_path_to_patient(net, "Sameera", "Samar"), sameeratosamar)
test2(find_path_to_patient(net, "Samar", "Sameera"), samartosameera)

test2(find_path_to_patient(net, "Kashif", "Samar"), kashiftosamar)
test2(find_path_to_patient(net, "Samar", "Kashif"), samartokashif)

test(find_path_to_patient(net, "Aisha", "Samar"), None)  # None
test(find_path_to_patient(net, "Kashif", "Arif"), None) # None
test(find_path_to_patient(net, "ABC", "DEF"), None)    # None
